# %%
## Census Demographics at county (city) geographic level

# %%
# data source: 2021 Census Data (ACS-1 year) for Selected Variables - Maryland

# %%
#See https://towardsdatascience.com/python-for-data-science-a-guide-to-data-visualization-with-plotly-969a59997d0c

# %%
# From https://www.census.gov/programs-surveys/acs/guidance/comparing-acs-data.html:
# "Due to the impact of the COVID-19 pandemic, the Census Bureau changed the 2020 ACS release. 
# Instead of providing the standard 1-year data products, the Census Bureau released experimental estimates from the 1-year data. 
# Data users should not compare 2020 ACS 1-year experimental estimates with any other data.""

# %%
pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (1.21.6)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (7.6.5)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (1.3.5)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (7.31.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (65.6.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cufflinks) (5.1.0)
# Requirement already satisfied: backcall in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: pygments in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.11.2)
# Requirement already satisfied: traitlets>=4.2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.7.1)
# Requirement already satisfied: decorator in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.36)
# Requirement already satisfied: jedi>=0.16 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: colorama in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (1.0.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.5.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (5.7.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.15.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from pandas>=0.19.2->cufflinks) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from plotly>=4.1.1->cufflinks) (7.0.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.8)
# Requirement already satisfied: debugpy>=1.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.1)
# Requirement already satisfied: tornado>=6.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.2)
# Requirement already satisfied: packaging in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (22.0)
# Requirement already satisfied: nest-asyncio in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.6)
# Requirement already satisfied: psutil in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: fastjsonschema in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (2.16.2)
# Requirement already satisfied: jupyter-core in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.11.2)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (5.0.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.16.0)
# Requirement already satisfied: wcwidth in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (4.4.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata>=3.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (3.11.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (0.18.0)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (1.3.10)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (22.1.0)
# Requirement already satisfied: entrypoints in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks) (305.1)
# Requirement already satisfied: nbconvert>=5 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.8.0)
# Requirement already satisfied: jinja2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.1.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.17.1)
# Requirement already satisfied: argon2-cffi in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.4.8)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.23.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.8.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.7.1)
# Requirement already satisfied: bleach in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.1.0)
# Requirement already satisfied: tinycss2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.1.1)
# Requirement already satisfied: lxml in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (4.9.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.13)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (21.2.0)
# Requirement already satisfied: websocket-client in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.58.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.5.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (3.4)
# Requirement already satisfied: pycparser in c:\users\jenkir\anaconda3\envs\pythondata\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->cufflinks) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import censusdata

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Jenkir\\Desktop\\cherry-tree-lane-analytics\\Medium-blog-post1\\census-demographics-city-level'

# %%
# need to change the working directory; be sure that the config file for the census API is also in this folder
#os.chdir('C:\\Users\\Jenkir\\Desktop\\ECO-iMPACT\\Medium-blog-post1')

# %%
#os.getcwd()

# %%
pd.set_option('display.max_rows', 200)

# %%
pd.set_option('max_colwidth', 200)

# %%
# Census American Community Survey 1-Year Data 

data = censusdata.download('acs1', 2021,
                          censusdata.censusgeo([('state', '24'),
                                         ('county', '*')]),
                                        ["B11005_002E","B19001_001E","B19301_001E","B15003_001E","B01003_001E", "B01002_001E",
                                         "B02001_002E", "B02001_003E","B03001_003E","B17001_002E","B17001_002E",
                                         "B19013_001E","B17001_002E","B23025_004E","B23025_005E","B15003_017E","B15003_021E",
                                         "B15003_022E","B25003_001E","B25003_002E","B02001_005E","B02001_008E","B25003_003E",
                                         "B19013A_001E","B19013B_001E","B19013D_001E","B19013G_001E","B19013G_001E",
                                         "B28003_005E", "B28003_006E"
                                        ])
                          
ACS1yr_2021 = pd.DataFrame(data)
ACS1yr_2021
# Out:
#                                                                             B11005_002E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037             77108
# Washington County, Maryland: Summary level: 050, state:24> county:043            108974
# Baltimore city, Maryland: Summary level: 050, state:24> county:510               405797
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003          409290
# Baltimore County, Maryland: Summary level: 050, state:24> county:005             589564
# Carroll County, Maryland: Summary level: 050, state:24> county:013               121642
# Charles County, Maryland: Summary level: 050, state:24> county:017               114590
# Howard County, Maryland: Summary level: 050, state:24> county:027                227684
# Prince George's County, Maryland: Summary level: 050, state:24> county:033       656295
# Wicomico County, Maryland: Summary level: 050, state:24> county:045               64960
#
#                                                                             B01003_001E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001               67729
# Calvert County, Maryland: Summary level: 050, state:24> county:009                93928
# Cecil County, Maryland: Summary level: 050, state:24> county:015                 103905
# Frederick County, Maryland: Summary level: 050, state:24> county:021             279835
# Harford County, Maryland: Summary level: 050, state:24> county:025               262977
# Montgomery County, Maryland: Summary level: 050, state:24> county:031           1054827
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037            114468
# Washington County, Maryland: Summary level: 050, state:24> county:043            154937
# Baltimore city, Maryland: Summary level: 050, state:24> county:510               576498
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003          590336
# Baltimore County, Maryland: Summary level: 050, state:24> county:005             849316
# Carroll County, Maryland: Summary level: 050, state:24> county:013               173873
# Charles County, Maryland: Summary level: 050, state:24> county:017               168698
# Howard County, Maryland: Summary level: 050, state:24> county:027                334529
# Prince George's County, Maryland: Summary level: 050, state:24> county:033       955306
# Wicomico County, Maryland: Summary level: 050, state:24> county:045              103980
#
#                                                                             B01002_001E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                41.3
# Calvert County, Maryland: Summary level: 050, state:24> county:009                 40.5
# Cecil County, Maryland: Summary level: 050, state:24> county:015                   41.3
# Frederick County, Maryland: Summary level: 050, state:24> county:021               38.8
# Harford County, Maryland: Summary level: 050, state:24> county:025                 39.6
# Montgomery County, Maryland: Summary level: 050, state:24> county:031              40.0
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037              37.2
# Washington County, Maryland: Summary level: 050, state:24> county:043              40.7
# Baltimore city, Maryland: Summary level: 050, state:24> county:510                 36.1
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003            38.4
# Baltimore County, Maryland: Summary level: 050, state:24> county:005               39.9
# Carroll County, Maryland: Summary level: 050, state:24> county:013                 41.3
# Charles County, Maryland: Summary level: 050, state:24> county:017                 39.0
# Howard County, Maryland: Summary level: 050, state:24> county:027                  39.9
# Prince George's County, Maryland: Summary level: 050, state:24> county:033         38.4
# Wicomico County, Maryland: Summary level: 050, state:24> county:045                35.9
#
#                                                                             B02001_002E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001               58436
# Calvert County, Maryland: Summary level: 050, state:24> county:009                69574
# Cecil County, Maryland: Summary level: 050, state:24> county:015                  86568
# Frederick County, Maryland: Summary level: 050, state:24> county:021             196751
# Harford County, Maryland: Summary level: 050, state:24> county:025               193467
# Montgomery County, Maryland: Summary level: 050, state:24> county:031            444151
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037             81593
# Washington County, Maryland: Summary level: 050, state:24> county:043            118329
# Baltimore city, Maryland: Summary level: 050, state:24> county:510               159246
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003          383429
# Baltimore County, Maryland: Summary level: 050, state:24> county:005             460054
# Carroll County, Maryland: Summary level: 050, state:24> county:013               152491
# Charles County, Maryland: Summary level: 050, state:24> county:017                59585
# Howard County, Maryland: Summary level: 050, state:24> county:027                161846
# Prince George's County, Maryland: Summary level: 050, state:24> county:033       119011
# Wicomico County, Maryland: Summary level: 050, state:24> county:045               62468
#
#                                                                             B02001_003E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                6267
# Calvert County, Maryland: Summary level: 050, state:24> county:009                10983
# Cecil County, Maryland: Summary level: 050, state:24> county:015                   7066
# Frederick County, Maryland: Summary level: 050, state:24> county:021              23707
# Harford County, Maryland: Summary level: 050, state:24> county:025                35964
# Montgomery County, Maryland: Summary level: 050, state:24> county:031            198493
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037             15788
# Washington County, Maryland: Summary level: 050, state:24> county:043             16329
# Baltimore city, Maryland: Summary level: 050, state:24> county:510               344531
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003          105360
# Baltimore County, Maryland: Summary level: 050, state:24> county:005             253139
# Carroll County, Maryland: Summary level: 050, state:24> county:013                 6069
# Charles County, Maryland: Summary level: 050, state:24> county:017                82697
# Howard County, Maryland: Summary level: 050, state:24> county:027                 69435
# Prince George's County, Maryland: Summary level: 050, state:24> county:033       572018
# Wicomico County, Maryland: Summary level: 050, state:24> county:045               25283
#
#                                                                             B03001_003E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                 NaN
# Calvert County, Maryland: Summary level: 050, state:24> county:009                  NaN
# Cecil County, Maryland: Summary level: 050, state:24> county:015                    NaN
# Frederick County, Maryland: Summary level: 050, state:24> county:021                NaN
# Harford County, Maryland: Summary level: 050, state:24> county:025                  NaN
# Montgomery County, Maryland: Summary level: 050, state:24> county:031          211512.0
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037               NaN
# Washington County, Maryland: Summary level: 050, state:24> county:043               NaN
# Baltimore city, Maryland: Summary level: 050, state:24> county:510              34810.0
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003         52841.0
# Baltimore County, Maryland: Summary level: 050, state:24> county:005            52983.0
# Carroll County, Maryland: Summary level: 050, state:24> county:013                  NaN
# Charles County, Maryland: Summary level: 050, state:24> county:017                  NaN
# Howard County, Maryland: Summary level: 050, state:24> county:027               25589.0
# Prince George's County, Maryland: Summary level: 050, state:24> county:033     194430.0
# Wicomico County, Maryland: Summary level: 050, state:24> county:045                 NaN
#
#                                                                             B17001_002E  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                8712
# Calvert County, Maryland: Summary level: 050, state:24> county:009                 4564
# Cecil County, Maryland: Summary level: 050, state:24> county:015                  12900
# Frederick County, Maryland: Summary level: 050, state:24> county:021              18622
# Harford County, Maryland: Summary level: 050, state:24> county:025                20461
# Montgomery County, Maryland: Summary level: 050, state:24> county:031             90377
# St. Mary's County, Maryland: Summary level: 050, state:24> county:037              8143
# Washington County, Maryland: Summary level: 050, state:24> county:043             24269
# Baltimore city, Maryland: Summary level: 050, state:24> county:510               127135
# Anne Arundel County, Maryland: Summary level: 050, state:24> county:003           33476
# Baltimore County, Maryland: Summary level: 050, state:24> county:005              81052
# Carroll County, Maryland: Summary level: 050, state:24> county:013                 7988
# Charles County, Maryland: Summary level: 050, state:24> county:017                 9018
# Howard County, Maryland: Summary level: 050, state:24> county:027                 21347
# Prince George's County, Maryland: Summary level: 050, state:24> county:033       107922
# Wicomico County, Maryland: Summary level: 050, state:24> county:045               13763
#
#                                                                             ...  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001         ...
# Calvert County, Maryland: Summary level: 050, state:24> county:009          ...
# Cecil County, Maryland: Summary level: 050, state:24> county:015            ...
# Frederick County, Maryland: Summary level: 050, state:24> county:021        ...
# Harford County, Maryland: Summary level: 050, state:24> county:025          ...
# Montgomery County, Maryland: Summary level: 050, state:24> county:031       ...
# St. Mary's County, Maryland: Summary level: 050, state:24> county:
# Charles County, Maryland: Summary level: 050, state:24> county:017                 1418
# Howard County, Maryland: Summary level: 050, state:24> county:027                  1490
# Prince George's County, Maryland: Summary level: 050, state:24> county:033        10537
# Wicomico County, Maryland: Summary level: 050, state:24> county:045                1891
#
# [16 rows x 27 columns]

# %%
# Replace the census variable codes (such as "B19013_001E") in the dataframe with the name of the detailed table variables so it's understandable
# I have the table id numbers listed in order so that it is easy to see what tables I have included at this point - can rearrange the column order later
ACS1yr_2021 = ACS1yr_2021.rename(columns={"B01003_001E": "Population",
                                      "B15003_001E": "Population 25 years and older",      
                                      "B01002_001E": "Median age", # universe: total population
                                      "B02001_003E": "Pop. Black", # universe: total population
                                      "B02001_002E": "Pop. white", # universe: total population
                                      "B02001_005E": "Pop. Asian",  # universe: total population      
                                      "B02001_008E": "Pop. 2 or more races", # universe: total population   
                                      "B03001_003E": "Pop. Hispanic origin", # universe: total population
                                      "B11005_002E": "Households with one or more people under 18 years",# universe: total households
                                      "B19301_001E":  "Per capita income", # universe: total population 
                                      "B15003_017E": "# persons age 25+ graduated high school", # universe: Population 25 years and over
                                      "B15003_021E": "# persons Associate's degree",   # universe: Population 25 years and over
                                      "B15003_022E": "# persons age 25+ with Bachelor's degree", # universe: Population 25 years and over
                                      "B17001_002E": " Persons for whom poverty status determined",    
                                      "B17001_002E": "Individuals- income below poverty level",# universe: persons for whom poverty status is determined
                                      "B19001_001E": "Total households",    
                                      "B19013_001E": "Median household income", # universe: total households
                                      "B19013A_001E": "Median HH income White Alone Householder", # universe: total households
                                      "B19013B_001E": "Median HH income Black or African American Alone Householder", # universe: total households
                                      "B19013D_001E": "Median HH income Asian Alone Householder", # universe: total households
                                      "B19013G_001E": "Median HH income two or more races Householder", # universe: total households
                                      "B19013G_001E": "Median HH income Hispanic or Latino Householder", # universe: total households 
                                      "B19301_001E":  "Per capita income", # universe: total population
                                      "B23025_002E": "In labor force", # universe: Population 16 years and over
                                      "B23025_004E": "Employed civilians", # universe: Population 16 years and over
                                      "B23025_005E": "Unemployedment civilians", # universe: Population 16 years and over
                                      "B25003_001E": "Total occupied units", # universe: Housing units
                                      "B25003_002E": "Total owner-occupied units", # universe: Housing units
                                      "B25003_003E": "Total renter-occupied units", # universe: Housing units
                                      "B28003_005E": "# households with computer, no internet subscription", # universe: total households
                                      "B28003_006E": "# households no computer",  # universe: total households  
                                      })
ACS1yr_2021.head()
# Out:
#                                                                       Households with one or more people under 18 years  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                                6608
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                                12273
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                                  10796
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                              36371
# Harford County, Maryland: Summary level: 050, state:24> county:025                                                29351
#
#                                                                       Total households  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001              28535
# Calvert County, Maryland: Summary level: 050, state:24> county:009               33994
# Cecil County, Maryland: Summary level: 050, state:24> county:015                 41000
# Frederick County, Maryland: Summary level: 050, state:24> county:021            103685
# Harford County, Maryland: Summary level: 050, state:24> county:025              101196
#
#                                                                       Per capita income  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001               28723
# Calvert County, Maryland: Summary level: 050, state:24> county:009                51999
# Cecil County, Maryland: Summary level: 050, state:24> county:015                  35232
# Frederick County, Maryland: Summary level: 050, state:24> county:021              47898
# Harford County, Maryland: Summary level: 050, state:24> county:025                44309
#
#                                                                       Population 25 years and older  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                           47636
# Calvert County, Maryland: Summary level: 050, state:24> county:009                            64805
# Cecil County, Maryland: Summary level: 050, state:24> county:015                              72911
# Frederick County, Maryland: Summary level: 050, state:24> county:021                         191943
# Harford County, Maryland: Summary level: 050, state:24> county:025                           183122
#
#                                                                       Population  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001        67729
# Calvert County, Maryland: Summary level: 050, state:24> county:009         93928
# Cecil County, Maryland: Summary level: 050, state:24> county:015          103905
# Frederick County, Maryland: Summary level: 050, state:24> county:021      279835
# Harford County, Maryland: Summary level: 050, state:24> county:025        262977
#
#                                                                       Median age  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001         41.3
# Calvert County, Maryland: Summary level: 050, state:24> county:009          40.5
# Cecil County, Maryland: Summary level: 050, state:24> county:015            41.3
# Frederick County, Maryland: Summary level: 050, state:24> county:021        38.8
# Harford County, Maryland: Summary level: 050, state:24> county:025          39.6
#
#                                                                       Pop. white  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001        58436
# Calvert County, Maryland: Summary level: 050, state:24> county:009         69574
# Cecil County, Maryland: Summary level: 050, state:24> county:015           86568
# Frederick County, Maryland: Summary level: 050, state:24> county:021      196751
# Harford County, Maryland: Summary level: 050, state:24> county:025        193467
#
#                                                                       Pop. Black  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001         6267
# Calvert County, Maryland: Summary level: 050, state:24> county:009         10983
# Cecil County, Maryland: Summary level: 050, state:24> county:015            7066
# Frederick County, Maryland: Summary level: 050, state:24> county:021       23707
# Harford County, Maryland: Summary level: 050, state:24> county:025         35964
#
#                                                                       Pop. Hispanic origin  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                    NaN
# Calvert County, Maryland: Summary level: 050, state:24> county:009                     NaN
# Cecil County, Maryland: Summary level: 050, state:24> county:015                       NaN
# Frederick County, Maryland: Summary level: 050, state:24> county:021                   NaN
# Harford County, Maryland: Summary level: 050, state:24> county:025                     NaN
#
#                                                                       Individuals- income below poverty level  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                      8712
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                       4564
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                        12900
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                    18622
# Harford County, Maryland: Summary level: 050, state:24> county:025                                      20461
#
#                                                                       ...  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001   ...
# Calvert County, Maryland: Summary level: 050, state:24> county:009    ...
# Cecil County, Maryland: Summary level: 050, state:24> county:015      ...
# Frederick County, Maryland: Summary level: 050, state:24> county:021  ...
# Harford County, Maryland: Summary level: 050, state:24> county:025    ...
#
#                                                                       Total owner-occupied units  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                        18523
# Calvert County, Maryland: Summary level: 050, state:24> county:009                         29469
# Cecil County, Maryland: Summary level: 050, state:24> county:015                           32006
# Frederick County, Maryland: Summary level: 050, state:24> county:021                       79433
# Harford County, Maryland: Summary level: 050, state:24> county:025                         80967
#
#                                                                       Pop. Asian  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001          811
# Calvert County, Maryland: Summary level: 050, state:24> county:009          2201
# Cecil County, Maryland: Summary level: 050, state:24> county:015            1290
# Frederick County, Maryland: Summary level: 050, state:24> county:021       14536
# Harford County, Maryland: Summary level: 050, state:24> county:025          8585
#
#                                                                       Pop. 2 or more races  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                   1826
# Calvert County, Maryland: Summary level: 050, state:24> county:009                   10412
# Cecil County, Maryland: Summary level: 050, state:24> county:015                      6755
# Frederick County, Maryland: Summary level: 050, state:24> county:021                 34710
# Harford County, Maryland: Summary level: 050, state:24> county:025                   18507
#
#                                                                       Total renter-occupied units  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                         10012
# Calvert County, Maryland: Summary level: 050, state:24> county:009                           4525
# Cecil County, Maryland: Summary level: 050, state:24> county:015                             8994
# Frederick County, Maryland: Summary level: 050, state:24> county:021                        24252
# Harford County, Maryland: Summary level: 050, state:24> county:025                          20229
#
#                                                                       Median HH income White Alone Householder  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                      50065
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                      128083
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                         81738
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                    112112
# Harford County, Maryland: Summary level: 050, state:24> county:025                                       99863
#
#                                                                       Median HH income Black or African American Alone Householder  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                                          50961
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                                           82588
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                                             52873
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                                         73492
# Harford County, Maryland: Summary level: 050, state:24> county:025                                                           72331
#
#                                                                       Median HH income Asian Alone Householder  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                               -666666666.0
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                    153325.0
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                       28787.0
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                  142143.0
# Harford County, Maryland: Summary level: 050, state:24> county:025                                    127866.0
#
#                                                                       Median HH income Hispanic or Latino Householder  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                             46217
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                             175897
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                                66462
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                            89595
# Harford County, Maryland: Summary level: 050, state:24> county:025                                             108121
#
#                                                                       # households with computer, no internet subscription  \
# Allegany County, Maryland: Summary level: 050, state:24> county:001                                                   2024
# Calvert County, Maryland: Summary level: 050, state:24> county:009                                                    1345
# Cecil County, Maryland: Summary level: 050, state:24> county:015                                                      2180
# Frederick County, Maryland: Summary level: 050, state:24> county:021                                                  3625
# Harford County, Maryland: Summary level: 050, state:24> county:025                                                    3608
#
#                                                                       # households no computer
# Allegany County, Maryland: Summary level: 050, state:24> county:001                       2475
# Calvert County, Maryland: Summary level: 050, state:24> county:009                        1244
# Cecil County, Maryland: Summary level: 050, state:24> county:015                          2161
# Frederick County, Maryland: Summary level: 050, state:24> county:021                      3584
# Harford County, Maryland: Summary level: 050, state:24> county:025                        2782
#
# [5 rows x 27 columns]

# %%
ACS_2021 = ACS1yr_2021.copy()
ACS_2021.columns
# Out:
# Index(['Households with one or more people under 18 years', 'Total households',
#        'Per capita income', 'Population 25 years and older', 'Population',
#        'Median age', 'Pop. white', 'Pop. Black', 'Pop. Hispanic origin',
#        'Individuals- income below poverty level', 'Median household income',
#        'Employed civilians', 'Unemployedment civilians',
#        '# persons age 25+ graduated high school',
#        '# persons Associate's degree',
#        '# persons age 25+ with Bachelor's degree', 'Total occupied units',
#        'Total owner-occupied units', 'Pop. Asian', 'Pop. 2 or more races',
#        'Total renter-occupied units',
#        'Median HH income White Alone Householder',
#        'Median HH income Black or African American Alone Householder',
#        'Median HH income Asian Alone Householder',
#        'Median HH income Hispanic or Latino Householder',
#        '# households with computer, no internet subscription',
#        '# households no computer'],
#       dtype='object')

# %%
ACSMD_2021 = ACS_2021.reset_index()
ACSMD_2021
# Out:
#                                                                          index  \
# 0          Allegany County, Maryland: Summary level: 050, state:24> county:001
# 1           Calvert County, Maryland: Summary level: 050, state:24> county:009
# 2             Cecil County, Maryland: Summary level: 050, state:24> county:015
# 3         Frederick County, Maryland: Summary level: 050, state:24> county:021
# 4           Harford County, Maryland: Summary level: 050, state:24> county:025
# 5        Montgomery County, Maryland: Summary level: 050, state:24> county:031
# 6        St. Mary's County, Maryland: Summary level: 050, state:24> county:037
# 7        Washington County, Maryland: Summary level: 050, state:24> county:043
# 8           Baltimore city, Maryland: Summary level: 050, state:24> county:510
# 9      Anne Arundel County, Maryland: Summary level: 050, state:24> county:003
# 10        Baltimore County, Maryland: Summary level: 050, state:24> county:005
# 11          Carroll County, Maryland: Summary level: 050, state:24> county:013
# 12          Charles County, Maryland: Summary level: 050, state:24> county:017
# 13           Howard County, Maryland: Summary level: 050, state:24> county:027
# 14  Prince George's County, Maryland: Summary level: 050, state:24> county:033
# 15         Wicomico County, Maryland: Summary level: 050, state:24> county:045
#
#     Households with one or more people under 18 years  Total households  \
# 0                                                6608             28535
# 1                                               12273             33994
# 2                                               10796             41000
# 3                                               36371            103685
# 4                                               29351            101196
# 5                                              131483            388396
# 6                                               14072             42078
# 7                                               16983             60215
# 8                                               55571            254370
# 9                                               72918            225064
# 10                                              95348            332529
# 11                                              20418             64161
# 12                                              20970             59481
# 13                                              48570            120546
# 14                                             106226            346127
# 15                                              11748             40577
#
#     Per capita income  Population 25 years and older  Population  Median age  \
# 0               28723                          47636       67729        41.3
# 1               51999                          64805       93928        40.5
# 2               35232                          72911      103905        41.3
# 3               47898                         191943      279835        38.8
# 4               44309                         183122      262977        39.6
# 5               60195                         732659     1054827        40.0
# 6               46099                          77108      114468        37.2
# 7               33336                         108974      154937        40.7
# 8               35091                         405797      576498        36.1
# 9               52865                         409290      590336        38.4
# 10              42839                         589564      849316        39.9
# 11              48760                         121642      173873        41.3
# 12              42878                         114590      168698        39.0
# 13              60404                         227684      334529        39.9
# 14              40248                         656295      955306        38.4
# 15              32200                          64960      103980        35.9
#
#     Pop. white  Pop. Black  Pop. Hispanic origin  ...  \
# 0        58436        6267                   NaN  ...
# 1        69574       10983                   NaN  ...
# 2        86568        7066                   NaN  ...
# 3       196751       23707                   NaN  ...
# 4       193467       35964                   NaN  ...
# 5       444151      198493              211512.0  ...
# 6        81593       15788                   NaN  ...
# 7       118329       16329                   NaN  ...
# 8       159246      344531               34810.0  ...
# 9       383429      105360               52841.0  ...
# 10      460054      253139               52983.0  ...
# 11      152491        6069                   NaN  ...
# 12       59585       82697                   NaN  ...
# 13      161846       69435               25589.0  ...
# 14      119011      572018              194430.0  ...
# 15       62468       25283                   NaN  ...
#
#     Total owner-occupied units  Pop. Asian  Pop. 2 or more races  \
# 0                        18523         811                  1826
# 1                        29469        2201                 10412
# 2                        32006        1290                  6755
# 3                        79433       14536                 34710
# 4                        80967        8585                 18507
# 5                       255211      164340                111808
# 6                        31926        3165                 11581
# 7                        38275        3186                 13564
# 8                       123249       14388                 35492
# 9                       167907       24149                 45192
# 10                      221944       52918                 55735
# 11                       54677        4584                  8710
# 12                       47426        5762                 15348
# 13                       89220       66297                 23436
# 14                      215180       36355                 72039
# 15                       25362        2244                  9144
#
#     Total renter-occupied units  Median HH income White Alone Householder  \
# 0                         10012                                     50065
# 1                          4525                                    128083
# 2                          8994                                     81738
# 3                         24252                                    112112
# 4                         20229                                     99863
# 5                        133185                                    141003
# 6                         10152                                    112760
# 7                         21940                                     68746
# 8                        131121                                     83740
# 9                         57157                                    117619
# 10                       110585                                     89149
# 11                         9484                                    103602
# 12                        12055                                     98508
# 13                        31326                                    145657
# 14                       130947                                    103408
# 15                        15215                                     65259
#
#     Median HH income Black or African American Alone Householder  \
# 0                                                          50961
# 1                                                          82588
# 2                                                          52873
# 3                                                          73492
# 4                                                          72331
# 5                                                          83194
# 6                                                          70348
# 7                                                          36599
# 8                                                          42825
# 9                                                          93438
# 10                                                         68813
# 11                                                        108095
# 12                                                        116452
# 13                                                        103477
# 14                                                         87764
# 15                                                         46631
#
#     Median HH income Asian Alone Householder  \
# 0                               -666666666.0
# 1                                   153325.0
# 2                                    28787.0
# 3                                   142143.0
# 4                                   127866.0
# 5                                   123183.0
# 6                                   104664.0
# 7                                    65659.0
# 8                                    55910.0
# 9                                    96875.0
# 10                                   96907.0
# 11                                   91327.0
# 12                                   69942.0
# 13                                  153194.0
# 14                                  105242.0
# 15                                       NaN
#
#     Median HH income Hispanic or Latino Householder  \
# 0                                             46217
# 1                                            175897
# 2                                             66462
# 3                                             89595
# 4                                            108121
# 5                                            107098
# 6                                            114935
# 7                                             49601
# 8                                             55905
# 9                                            115968
# 10                                            68192
# 11                                           100548
# 12                                           115038
# 13                                           112804
# 14                                            85225
# 15                                            91349
#
#     # households with computer, no internet subscription  \
# 0                                                   2024
# 1                                                   1345
# 2                                                   2180
# 3                                                   3625
# 4                                                   3608
# 5                                                  10917
# 6                                                   2099
# 7                                                   6276
# 8                                                  29335
# 9                                                   5200
# 10                                                 15054
# 11                                                  3208
# 12                                                  2860
# 13                                                  2350
# 14                                                 15172
# 15                                                  4150
#
#     # households no computer
# 0                       2475
# 1                       1244
# 2                       2161
# 3                       3584
# 4                       2782
# 5                       6410
# 6                       1907
# 7                       4779
# 8                      15562
# 9                       5339
# 10                     15369
# 11                      2798
# 12                      1418
# 13                      1490
# 14                     10537
# 15                      1891
#
# [16 rows x 28 columns]

# %%
ACSMD_2021 = ACSMD_2021.rename(columns={"index": "County/ city"})                                           
ACSMD_2021.dtypes
# Out:
# County/ city                                                     object
# Households with one or more people under 18 years                 int64
# Total households                                                  int64
# Per capita income                                                 int64
# Population 25 years and older                                     int64
# Population                                                        int64
# Median age                                                      float64
# Pop. white                                                        int64
# Pop. Black                                                        int64
# Pop. Hispanic origin                                            float64
# Individuals- income below poverty level                           int64
# Median household income                                           int64
# Employed civilians                                                int64
# Unemployedment civilians                                          int64
# # persons age 25+ graduated high school                           int64
# # persons Associate's degree                                      int64
# # persons age 25+ with Bachelor's degree                          int64
# Total occupied units                                              int64
# Total owner-occupied units                                        int64
# Pop. Asian                                                        int64
# Pop. 2 or more races                                              int64
# Total renter-occupied units                                       int64
# Median HH income White Alone Householder                          int64
# Median HH income Black or African American Alone Householder      int64
# Median HH income Asian Alone Householder                        float64
# Median HH income Hispanic or Latino Householder                   int64
# # households with computer, no internet subscription              int64
# # households no computer                                          int64
# dtype: object

# %%
#See  https://medium.com/@akaivdo/how-to-split-one-column-to-multiple-columns-in-pandas-3c857b47fbde

ACSMD_2021[['County/ city', 'state', 'other']] = ACSMD_2021['County/ city'].str.split(",",expand=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16364\418693899.py in <module>
# ----> 1 ACSMD_2021[['County/ city', 'state', 'other']] = ACSMD_2021['County/ city'].str.split(",",expand=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3598             self._setitem_frame(key, value)
#    3599         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
#    3602             self._set_item_frame_value(key, value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3637         else:
#    3638             if isinstance(value, DataFrame):
# -> 3639                 check_key_length(self.columns, key, value)
#    3640                 for k1, k2 in zip(key, value.columns):
#    3641                     self[k1] = value[k2]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexers.py in check_key_length(columns, key, value)
#     426     if columns.is_unique:
#     427         if len(value.columns) != len(key):
# --> 428             raise ValueError("Columns must be same length as key")
#     429     else:
#     430         # Missing keys in columns are represented as -1
#
# ValueError: Columns must be same length as key

# %%
ACSMD_2021

# %%
# combine the ACS1yr_2021 dataframe with the age_finaldataframe 
demographics_2021 = pd.merge(
    ACS1yr_2021, age_final, on="Year", how="outer")
demographics_2021

# %%
demographics_2021["Percent Black"] =(100 * \
    demographics_2021["Pop. Black"].astype(
        int) / demographics_2021["Population"].astype(
        int)).round(1) 

demographics_2021

# %%
demographics_2021["Percent white"] =(100 * \
    demographics_2021["Pop. white"].astype(
        int) / demographics_2021["Population"].astype(
        int)).round(1) 

demographics_2021

# %%
demographics_2021["Percent working age pop."] = 100 * \
    demographics_2021["Pop. working age"].astype(
        int) / demographics_2021["Population"].astype(
        int) 

demographics_2021["Percent working age pop."] = demographics_2021["Percent working age pop."].astype(int)

# %%
demographics_2021["Percent households with children"] = 100 * \
    demographics_2021["Households with one or more people under 18 years"].astype(
        int) / demographics_2021["Total households"].astype(
        int) 

demographics_2021["Percent households with children"] = demographics_2021["Percent households with children"].astype(int)
demographics_2021

# %%
# Export file as a CSV, without the Pandas index, but with the header
#demographics_2021.to_csv("ACS_demographics_2021.csv", index = False, header=True)

# %%
# Plotly dashboard example   https://towardsdatascience.com/creating-an-interactive-dashboard-with-dash-plotly-using-crime-data-a217da841df3
